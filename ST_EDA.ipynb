# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
mother_path = "D:\\2.ProjectWork\\1.TEX"
machine_number = "25TEX_009"
phase_number = "P01"
model_folder ="04"
result_folder = "06"

fea_name = "F"
dev_name = "D"

fea_list = [
"F1",
"F2",
"F3",
"F4",
"F5"
]


project_path = mother_path +"\\" + machine_number + "\\"+ machine_number + "_" + phase_number 
intial_fol_path = project_path + "\\" + machine_number + "_" + phase_number + "_" + model_folder
dest_fol_path =  project_path + "\\" + machine_number + "_" + phase_number + "_" + result_folder



file_detials = os.listdir(intial_fol_path)


data_train = []
for file in file_detials:
    file_path = os.path.join(intial_fol_path,file)
    df = pd.read_excel(file_path)
    data_train.append(df)
all_data = pd.concat(data_train)

# %%
all_data
# Out:
#          D1        F1         F2       F3        F4        F5
# 0   -0.2090    100.01  22.000000  551.841  2265.308  2845.533
# 1   -0.2075    200.03  22.017000  551.841  2265.308  2845.533
# 2   -0.2050    300.04  22.035000  551.841  2265.308  2845.533
# 3   -0.2025    400.05  22.052000  551.841  2265.308  2845.533
# 4   -0.1985    500.07  22.069000  551.841  2265.308  2845.533
# ..      ...       ...        ...      ...       ...       ...
# 301  0.2660  30218.00  26.934000  356.877  2013.632  1507.688
# 302  0.2630  30318.00  26.951000  356.877  2013.632  1507.688
# 303  0.2670  30418.00  26.967000  356.877  2013.632  1507.688
# 304  0.2670  30518.00  26.984000  356.877  2013.632  1507.688
# 305  0.2670  30618.00  27.000067  356.877  2013.632  1507.688
#
# [1530 rows x 6 columns]

# %%
# sns.pairplot(data)

# %%
plt.figure(figsize=(10,6))
print(sns.displot(all_data["D1"]))
# print(sns.displot(data["Y-Axis"]))
# print(sns.displot(data["Z-Axis"]))
# Out:
# <seaborn.axisgrid.FacetGrid object at 0x000001389128D700>

# %%
all_data.corr()
# data.corr()['X-Axis'].sort_values()
# Out:
#           D1        F1        F2        F3        F4        F5
# D1  1.000000 -0.044151 -0.034614 -0.935445  0.448419 -0.245767
# F1 -0.044151  1.000000  0.999009  0.000122 -0.000325 -0.000170
# F2 -0.034614  0.999009  1.000000 -0.008609 -0.007851 -0.007293
# F3 -0.935445  0.000122 -0.008609  1.000000 -0.286277  0.466487
# F4  0.448419 -0.000325 -0.007851 -0.286277  1.000000  0.676178
# F5 -0.245767 -0.000170 -0.007293  0.466487  0.676178  1.000000

# %%
plt.figure(figsize=(20,12))
sns.heatmap(all_data.corr(),cmap='viridis',annot=True)
# Out:
# <Axes: >

# %%
all_data.to_excel(r"D:\2.ProjectWork\1.TEX\25TEX_009\25TEX_009_P01\SJE-10 all_data.xlsx")
